# %% [markdown]
# #A Python function to check whether the number is Prime or Not

# %%
def primeCheck(no):
  for i in range(2,no) :
    if no % i == 0:
      print(no,"is not a prime number")
      break
  else :
      print(no,"is a prime number")

# %%
primeCheck(15)
# Out:
# 15 is not a prime number

# %%
primeCheck(17)
# Out:
# 17 is a prime number
